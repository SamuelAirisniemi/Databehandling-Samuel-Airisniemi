# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

college = pd.read_csv("C:/Users/samue/Documents/code/Databehandling-Samuel-Airisniemi/Laboration-Databehandling/College.csv")

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv("C:/Users/samue/Documents/code/Databehandling-Samuel-Airisniemi/Laboration-Databehandling/College.csv", index_col = 0)
college3 = college.rename({"Unnamed: 0": "College"}, axis = 1)
college3 = college3.set_index("College")

# %%
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college = college3
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
C = ["Top10perc", "Apps", "Enroll"]
pd.plotting.scatter_matrix(college[C])
plt.show()

# %%
sns.boxplot(x = "Private", y = "Outstate", data = college)
# Out:
# <Axes: xlabel='Private', ylabel='Outstate'>

# %%
college["Elite"] = pd.cut(college["Top10perc"],[0, 50, 100], labels = ["No", "Yes"])
print(college["Elite"].value_counts())
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
sns.boxplot(x = "Elite", y = "Outstate", data = college)
# Out:
# <Axes: xlabel='Elite', ylabel='Outstate'>

# %%
fig, axes = plt.subplots(2, 2)

college["Apps"].plot.hist(bins=10, ax=axes[0,0])
axes[0,0].set_title("Applications (10 bins)")

college["Accept"].plot.hist(bins=20, ax=axes[0,1])
axes[0,1].set_title("Acceptances (20 bins)")

college["Enroll"].plot.hist(bins=30, ax=axes[1,0])
axes[1,0].set_title("Enrollments (30 bins)")

college["Top10perc"].plot.hist(bins=40, ax=axes[1,1])
axes[1,1].set_title("Top 10% (40 bins)")

plt.tight_layout()
plt.show()

# %%
college["Elite"] = pd.cut(college["Top10perc"], bins = [0, 50, 100], labels = ["No", "Yes"])

fig, axes = plt.subplots(1, 2, figsize = (16, 6))

sns.scatterplot(x = "Personal", y = "Expend", hue = "Elite", ax = axes[0], data = college)

axes[0].set_title("Instructional vs Personal Spending by Elite Status")
axes[0].set_xlabel("Personal Spending")
axes[0].set_ylabel("Instructional Spending")

melted = college.melt(id_vars = "Elite", value_vars = ["Expend", "Personal"])
sns.boxplot(data = melted, x = "variable", y = "value", hue = "Elite", ax = axes[1])
axes[1].set_title("Spending Distributions by Elite Status")
axes[1].set_xlabel("Spending Category")
axes[1].set_ylabel("Amount")

plt.tight_layout()
plt.show()

#plt.figure(figsize = (10, 6))
#sns.scatterplot(data=college, x = "Expend", y = "Personal", hue = "Elite")
#plt.title("Instructional Spending vs Personal Spending by Elite Status")
#plt.xlabel("Instructional Spending")
#plt.ylabel("Personal Spending")
#plt.legend(title="Elite Status")
#plt.show()

# %% [markdown]
# Fråga: Finns det ett samband mellan personliga utgifter och elitstatus?
#
# Här undersöker vi en jämförelse av utbildningsutgifter och personliga utgifter beroende om man läser elituniversitet eller inte. Vi kan se ett tydligt mönster där elituniversitet spenderar betydligt mycket mer på undervisning. Det finns också en korrelation mellan "Expend" och "Personal", vilket betyder att skolor som investerar mer i undervisning ofta har högre personliga utgifter. I boxplot grafen ser vi även att elituniversitet spenderar mycket mer än icke-elituniversitet. Nästan 2-3x så mycket.
#
# Vi ser även en överlappning mellan elit och icke-elit. Vilket tyder på att även om undervisningsutgifter är en stark differentieringsfaktor så påverkas personliga utgifter också av andra faktorer (plats, elevdemografi, leveranskostnad). Elituniversitet är starkt kopplad till undervisningsutgifter. Vilket vi kan anta eftersom elituniversitet ofta har större anslag och har råd med högre lärarlöner, mindre klasser och mer resurser. Personliga utgifter är mindre starkt kopplad till elituniversitet men trenden är fortfarande uppåtgående. Studenter på elituniversitet kan ha högre levnadskostnader och mer valfria utgifter.

# %%
college.boxplot(column = "Grad.Rate", by = "Private")

plt.title("Graduation Rate by College Type")
plt.suptitle("")
plt.xlabel("Private College")
plt.ylabel("Graduation Rate")
plt.show()

# %%
college = pd.read_csv("College.csv", index_col=0)

#sns.set(style="Whitegrid", context = "Talk")
fig, axes = plt.subplots(1, 2, figsize = (14, 6))

sns.regplot(data = college, x = "PhD", y = "Grad.Rate", ax = axes[0], scatter_kws = {"alpha":0.6}, line_kws = {"color":"red"})

axes[0].set_title("Graduation Rate vs Faculty with PhDs")
axes[0].set_xlabel("Faculty with PhD %")
axes[0].set_ylabel("Graduation Rate %")

sns.regplot(data = college, x = "Terminal", y = "Grad.Rate", ax = axes[1], scatter_kws = {"alpha":0.6}, line_kws = {"color":"red"})

axes[1].set_title("Graduation Rate vs Faculty with Terminal Degrees")
axes[1].set_xlabel("Faculty with Terminal Degrees %")
axes[1].set_ylabel("Graduation Rate %")

plt.tight_layout()
plt.show()

# %%
phd_bins = pd.cut(college["PhD"], bins = [0, 40, 60, 80, 100], labels = ["0-40%", "41-60%", "61-80%", "81-100%"])
terminal_bins = pd.cut(college["Terminal"], bins = [0, 40, 60, 80, 100], labels =   ["0-40%", "41-60%", "61-80%", "81-100%"])

phd_grad_rate = college.groupby(phd_bins)["Grad.Rate"].mean()
terminal_grad_rate = college.groupby(terminal_bins)["Grad.Rate"].mean()

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

phd_grad_rate.plot(kind="bar", ax=axes[0], color="skyblue", edgecolor="black")
axes[0].set_title("Average Graduation Rate by % Faculty with PhD")
axes[0].set_xlabel("PhD Percentage Bin")
axes[0].set_ylabel("Average Graduation Rate (%)")
axes[0].grid(True)

terminal_grad_rate.plot(kind="bar", ax=axes[1], color="salmon", edgecolor="black")
axes[1].set_title("Average Graduation Rate by % Faculty with Terminal Degree")
axes[1].set_xlabel("Terminal Degree Percentage Bin")
axes[1].set_ylabel("Average Graduation Rate (%)")
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_19332\3525554948.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   phd_grad_rate = college.groupby(phd_bins)["Grad.Rate"].mean()
# C:\Users\samue\AppData\Local\Temp\ipykernel_19332\3525554948.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   terminal_grad_rate = college.groupby(terminal_bins)["Grad.Rate"].mean()
